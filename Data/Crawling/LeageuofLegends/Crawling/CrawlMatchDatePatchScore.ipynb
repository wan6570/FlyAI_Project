# %%
import pandas as pd

stats_df = pd.read_csv('../../../RawData/GameStats/LCK_2023_SUMMER.csv')
stats_df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2055   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2056     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2057     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2058    Viper       Jinx      ADC     13      0       1        1    1  265
# 2059     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
#       CS in Team's Jungle  ...  Damage self mitigated  \
# ...

# %%
df = pd.read_csv('../../../RawData/GameStats/LCK_2023_SUMMER_Overview.csv')
df
# Out:
#                     1      2                    3      4      5           6  \
# 0          KT Rolster  2 - 0         Liiv SANDBOX  WEEK9  13.14  2023-08-06
# 1                 DRX  2 - 0     Kwangdong Freecs  WEEK9  13.14  2023-08-06
# 2               BRION  2 - 0        Gen.G eSports  WEEK9  13.14  2023-08-05
# 3           Dplus KIA  0 - 2  Hanwha Life eSports  WEEK9  13.14  2023-08-05
# 4   Nongshim RedForce  1 - 2           KT Rolster  WEEK9  13.14  2023-08-04
# ..                ...    ...                  ...    ...    ...         ...
# 85         KT Rolster  1 - 2        Gen.G eSports  WEEK1  13.10  2023-06-09
# 86              BRION  1 - 2    Nongshim RedForce  WEEK1  13.10  2023-06-08
# 87   Kwangdong Freecs  2 - 0                  DRX  WEEK1  13.10  2023-06-08
# 88          Dplus KIA  2 - 0         Liiv SANDBOX  WEEK1  13.10  2023-06-07
# 89         KT Rolster  2 - 1  Hanwha Life eSports  WEEK1  13.10  2023-06-07
#
#     total_game
# 0            2
# 1            2
# ...

# %%
extra_info = {
    'Version' : [],
    'Date' : []
}

# %%
a = []
a.append(df.loc[0, '6'])

# %%
print(df.shape[0])

for i in range(df.shape[0]):
    repeat = df.loc[i, 'total_game']
    version = df.loc[i, '5']
    date = df.loc[i, '6']



    for j in range(repeat * 10):
        extra_info['Version'].append(version)
        extra_info['Date'].append(date)

print(len(extra_info['Date']))
# Out:
# 90
# 2060

# %%
extra_info_df = pd.DataFrame(extra_info)
extra_info_df
# Out:
#       Version        Date
# 0       13.14  2023-08-06
# 1       13.14  2023-08-06
# 2       13.14  2023-08-06
# 3       13.14  2023-08-06
# 4       13.14  2023-08-06
# ...       ...         ...
# 2055    13.10  2023-06-07
# 2056    13.10  2023-06-07
# 2057    13.10  2023-06-07
# 2058    13.10  2023-06-07
# 2059    13.10  2023-06-07
#
# [2060 rows x 2 columns]

# %%
import pandas as pd

df = pd.concat([stats_df, extra_info_df], axis = 1)
df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2055   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2056     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2057     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2058    Viper       Jinx      ADC     13      0       1        1    1  265
# 2059     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
# ...

# %%
len(df['Player'].unique())
# Out:
# 66

# %%
team = {
    'KT' : ['Kiin', 'PerfecT','Cuzz', 'Bdd', 'Aiming', 'Hype','Lehends', 'Way'],
    'GEN' : ['Doran', 'Peanut', 'Chovy', 'Peyz', 'Delight'],
    'HLE' : ['kingen', 'Grizzly', 'Clid', 'Zeka', 'Viper', 'Life'],
    'Dplus KIA' : ['Canna', 'Canyon', 'ShowMaker', 'Deft', 'Rahel','Bible', 'Kellin'],
    'T1' : ['Zeus', 'Oner', 'Faker', 'Poby', 'Gumayusi', 'Keria'],
    'DRX' : ['Rascal', 'Croco','Juhan', 'FATE', 'Kyeahoo','Paduck', 'BeryL'],
    'LSB' : ['Burdol', 'Clear', 'Willer', 'HamBak','Clozer', 'Feisty','Teddy', 'Kael'],
    'BRION' : ['Morgan', 'UmTi', 'Karis', 'Ivory','Hena', 'Effort'],
    'NS' : ['DnDn','Sylvie', 'FIESTA', 'Quad', 'Jiwoo', 'Vital','Peter'],
    'KDF' : ['DuDu', 'YoungJae', 'Bulldog', 'Taeyoon', 'Andil', 'Jun', 'Andil']
}

player_to_team = {}
for team_name, players in team.items():
    for player in players:
        player_to_team[player] = team_name
    
print(player_to_team)
# Out:
# {'Kiin': 'KT', 'PerfecT': 'KT', 'Cuzz': 'KT', 'Bdd': 'KT', 'Aiming': 'KT', 'Hype': 'KT', 'Lehends': 'KT', 'Way': 'KT', 'Doran': 'GEN', 'Peanut': 'GEN', 'Chovy': 'GEN', 'Peyz': 'GEN', 'Delight': 'GEN', 'kingen': 'HLE', 'Grizzly': 'HLE', 'Clid': 'HLE', 'Zeka': 'HLE', 'Viper': 'HLE', 'Life': 'HLE', 'Canna': 'Dplus KIA', 'Canyon': 'Dplus KIA', 'ShowMaker': 'Dplus KIA', 'Deft': 'Dplus KIA', 'Rahel': 'Dplus KIA', 'Bible': 'Dplus KIA', 'Kellin': 'Dplus KIA', 'Zeus': 'T1', 'Oner': 'T1', 'Faker': 'T1', 'Poby': 'T1', 'Gumayusi': 'T1', 'Keria': 'T1', 'Rascal': 'DRX', 'Croco': 'DRX', 'Juhan': 'DRX', 'FATE': 'DRX', 'Kyeahoo': 'DRX', 'Paduck': 'DRX', 'BeryL': 'DRX', 'Burdol': 'LSB', 'Clear': 'LSB', 'Willer': 'LSB', 'HamBak': 'LSB', 'Clozer': 'LSB', 'Feisty': 'LSB', 'Teddy': 'LSB', 'Kael': 'LSB', 'Morgan': 'BRION', 'UmTi': 'BRION', 'Karis': 'BRION', 'Ivory': 'BRION', 'Hena': 'BRION', 'Effort': 'BRION', 'DnDn': 'NS', 'Sylvie': 'NS', 'FIESTA': 'NS', 'Quad': 'NS', 'Jiwoo': 'NS', 'Vital': 'NS', 'Peter'
# ...

# %%
df.loc[:,'Team'] = df['Player'].map(player_to_team)

# %%
df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2055   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2056     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2057     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2058    Viper       Jinx      ADC     13      0       1        1    1  265
# 2059     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
# ...

# %%
df[df['Team'] == 'KT']
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists          KDA  \
# 0        Kiin  Gangplank      TOP     16      2       1        8           10
# 1        Cuzz      Viego   JUNGLE     15      8       2       10            9
# 2         Bdd       Ahri      MID     15      7       3       10          5.7
# 3      Aiming   Tristana      ADC     15      0       2       13          6.5
# 4     Lehends    Alistar  SUPPORT     12      2       3       11          4.3
# ...       ...        ...      ...    ...    ...     ...      ...          ...
# 2050     Kiin       Sion      TOP     15      3       1        1            4
# 2051     Cuzz   Volibear   JUNGLE     13      2       1        6            8
# 2052      Bdd      Annie      MID     15      1       0        6  Perfect KDA
# 2053   Aiming   Aphelios      ADC     13      4       0        4  Perfect KDA
# 2054  Lehends      Yuumi  SUPPORT     12      0       0        9  Perfect KDA
#
# ...

# %%
result = []
for i in range(df.shape[0]):
    result.append('Win')

# %%
df['Result'] = result

# %%
df.to_csv('../../../RawData/GameStats/LCK_2023_SUMMER_With_Team.csv')

# %%
teams_to_change = ['LSB', 'DRX', 'KDF', 'BRION', 'NS']
df.loc[df['Team'].isin(teams_to_change), 'Result'] = 'Lose'

df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2055   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2056     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2057     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2058    Viper       Jinx      ADC     13      0       1        1    1  265
# 2059     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
# ...
