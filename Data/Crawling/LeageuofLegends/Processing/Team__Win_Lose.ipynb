# %%
import pandas as pd

df = pd.read_csv('../../../RawData/GameStats/LCK_2023_SUMMER.csv')
df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2065   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2066     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2067     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2068    Viper       Jinx      ADC     13      0       1        1    1  265
# 2069     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
#       CS in Team's Jungle  ...  Damage self mitigated  \
# ...

# %%
df[(df.isna() == True).sum(axis=1) > 2]
# Out:
#        Player  Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 115     Clear   K'Sante      TOP      3      4       1       12   16  369
# 116    Willer  Nocturne   JUNGLE      3      6       3       11  5.7  259
# 117    Clozer      Ahri      MID      4      8       3       10    6  367
# 118     Teddy    Kai'Sa      ADC      3      8       3       15  7.7  469
# 119      Kael      Rell  SUPPORT      3      1       2       21   11   35
# 120      Zeus      Gnar      TOP      3      3       2        8  5.5  436
# 121      Oner   Sejuani   JUNGLE      4      1       6        6  1.2  186
# 122     Faker  Tristana      MID      4      1       8        6  0.9  356
# 123  Gumayusi      Zeri      ADC      2      7       5        4  2.2  463
# 124     Keria     Xayah  SUPPORT      2      0       6       11  1.8   46
#
#      CS in Team's Jungle  ...  Total Damage Shielded On Teammates  \
# 115                  NaN  ...                                   0
# ...

# %%
df['Player'].value_counts()
# Out:
# UmTi       45
# Hena       45
# Morgan     45
# Effort     45
# Rascal     43
#            ..
# Hype        1
# PerfecT     1
# HamBak      1
# Feisty      1
# Way         1
# Name: Player, Length: 75, dtype: int64

# %%
less_than_10 = df['Player'].value_counts() <= 10

less_than_10.index[less_than_10 == True]
# Out:
# Index(['Ivory', 'Kyeahoo', 'Vital', 'Rahel', 'Sponge', 'SeTab', 'deokdam',
#        'Pleata', 'Mihile', 'Sounda', 'Callme', 'Frog', 'HH', 'Hype', 'PerfecT',
#        'HamBak', 'Feisty', 'Way'],
#       dtype='object')

# %%
df['Player'].isin(less_than_10.index[less_than_10 == False])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2065    True
# 2066    True
# 2067    True
# 2068    True
# 2069    True
# Name: Player, Length: 2070, dtype: bool

# %%
drop_less_than_10_df = df[df['Player'].isin(less_than_10.index[less_than_10 == False])]

drop_less_than_10_df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2065   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2066     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2067     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2068    Viper       Jinx      ADC     13      0       1        1    1  265
# 2069     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
#       CS in Team's Jungle  ...  Damage self mitigated  \
# ...

# %%
top_df = drop_less_than_10_df[drop_less_than_10_df['Role'] == 'SUPPORT']
print(top_df['Player'].unique())
print(len(top_df['Player'].unique()))
# Out:
# ['Lehends' 'Kael' 'BeryL' 'Andil' 'Effort' 'Delight' 'Bible' 'Life'
#  'Peter' 'Keria' 'Kellin' 'Jun']
# 12

# %%
team = {
    'KT' : ['Kiin', 'Cuzz', 'Bdd', 'Aiming', 'Lehends'],
    'GEN' : ['Doran', 'Peanut', 'Chovy', 'Peyz', 'Delight'],
    'HLE' : ['kingen', 'Grizzly', 'Clid', 'Zeka', 'Viper', 'Life'],
    'Dplus KIA' : ['Canna', 'Canyon', 'ShowMaker', 'Deft', 'Bible', 'Kellin'],
    'T1' : ['Zeus', 'Oner', 'Faker', 'Poby', 'Gumayusi', 'Keria'],
    'DRX' : ['Rascal', 'Croco','Juhan', 'FATE', 'Paduck', 'BeryL'],
    'LSB' : ['Burdol', 'Clear', 'Willer', 'Clozer', 'Teddy', 'Kael'],
    'BRION' : ['Morgan', 'UmTi', 'Karis', 'Hena', 'Effort'],
    'NS' : ['DnDn','Sylvie', 'FIESTA', 'Quad', 'Jiwoo', 'Peter'],
    'KDF' : ['DuDu', 'YoungJae', 'Bulldog', 'Taeyoon', 'Andil', 'Jun']
}

# %%
player_to_team = {}
for team_name, players in team.items():
    for player in players:
        player_to_team[player] = team_name
    
print(player_to_team)
# Out:
# {'Kiin': 'KT', 'Cuzz': 'KT', 'Bdd': 'KT', 'Aiming': 'KT', 'Lehends': 'KT', 'Doran': 'GEN', 'Peanut': 'GEN', 'Chovy': 'GEN', 'Peyz': 'GEN', 'Delight': 'GEN', 'kingen': 'HLE', 'Grizzly': 'HLE', 'Clid': 'HLE', 'Zeka': 'HLE', 'Viper': 'HLE', 'Life': 'HLE', 'Canna': 'Dplus KIA', 'Canyon': 'Dplus KIA', 'ShowMaker': 'Dplus KIA', 'Deft': 'Dplus KIA', 'Bible': 'Dplus KIA', 'Kellin': 'Dplus KIA', 'Zeus': 'T1', 'Oner': 'T1', 'Faker': 'T1', 'Poby': 'T1', 'Gumayusi': 'T1', 'Keria': 'T1', 'Rascal': 'DRX', 'Croco': 'DRX', 'Juhan': 'DRX', 'FATE': 'DRX', 'Paduck': 'DRX', 'BeryL': 'DRX', 'Burdol': 'LSB', 'Clear': 'LSB', 'Willer': 'LSB', 'Clozer': 'LSB', 'Teddy': 'LSB', 'Kael': 'LSB', 'Morgan': 'BRION', 'UmTi': 'BRION', 'Karis': 'BRION', 'Hena': 'BRION', 'Effort': 'BRION', 'DnDn': 'NS', 'Sylvie': 'NS', 'FIESTA': 'NS', 'Quad': 'NS', 'Jiwoo': 'NS', 'Peter': 'NS', 'DuDu': 'KDF', 'YoungJae': 'KDF', 'Bulldog': 'KDF', 'Taeyoon': 'KDF', 'Andil': 'KDF', 'Jun': 'KDF'}

# %%
drop_less_than_10_df.loc[:,'Team'] = drop_less_than_10_df['Player'].map(player_to_team)
# Out:
# C:\Users\jongwan\AppData\Local\Temp\ipykernel_22964\2314909516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_less_than_10_df.loc[:,'Team'] = drop_less_than_10_df['Player'].map(player_to_team)

# %%
drop_less_than_10_df['Team'].value_counts()
# Out:
# BRION        215
# T1           210
# NS           208
# DRX          206
# HLE          205
# KT           200
# LSB          200
# Dplus KIA    197
# GEN          195
# KDF          190
# Name: Team, dtype: int64

# %%
drop_less_than_10_df.to_csv('../../../ProcessedData/LCK_2023_SUMMER_AddTeam_DropSubs.csv', index=False)

# %%
df = pd.read_csv('../../../ProcessedData/LCK_2023_SUMMER_AddTeam_DropSubs.csv')
df
# Out:
#        Player   Champion     Role  Level  Kills  Deaths  Assists  KDA   CS  \
# 0        Kiin  Gangplank      TOP     16      2       1        8   10  252
# 1        Cuzz      Viego   JUNGLE     15      8       2       10    9  182
# 2         Bdd       Ahri      MID     15      7       3       10  5.7  219
# 3      Aiming   Tristana      ADC     15      0       2       13  6.5  264
# 4     Lehends    Alistar  SUPPORT     12      2       3       11  4.3   30
# ...       ...        ...      ...    ...    ...     ...      ...  ...  ...
# 2021   kingen    K'Sante      TOP     15      1       1        1    2  250
# 2022     Clid      Viego   JUNGLE     13      1       2        1    1  164
# 2023     Zeka     Gragas      MID     14      0       3        1  0.3  226
# 2024    Viper       Jinx      ADC     13      0       1        1    1  265
# 2025     Life      Milio  SUPPORT      9      0       3        1  0.3   12
#
# ...

# %%
[df.isna().sum(axis = 0) > 0]
# Out:
# [Player                                False
#  Champion                              False
#  Role                                  False
#  Level                                 False
#  Kills                                 False
#  Deaths                                False
#  Assists                               False
#  KDA                                   False
#  CS                                    False
#  CS in Team's Jungle                    True
#  CS in Enemy Jungle                     True
#  CSM                                   False
#  Golds                                 False
#  GPM                                   False
#  GOLD%                                 False
#  Vision Score                           True
#  Wards placed                           True
#  Wards destroyed                        True
#  Control Wards Purchased                True
#  Detector Wards Placed                 False
#  VSPM                                   True
# ...
