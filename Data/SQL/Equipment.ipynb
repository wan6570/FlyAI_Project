# %%
import pandas as pd

df = pd.read_csv('Equipment.csv')

# %%
df = df[['Player','Mouse', 'Keyboard']]
df
# Out:
#        Player                         Mouse                   Keyboard
# 0        Kiin                Abko A660 3360              Logitech G512
# 1        Cuzz           Logitech G Pro Hero          Logitech G913 TKL
# 2         Bdd            Logitech G903 HERO  Logitech G Pro X Keyboard
# 3      Aiming            Logitech G903 HERO              Logitech G512
# 4     Lehends       Logitech G PRO WIRELESS                Corsair K68
# 5      Rascal                 Logitech G903             Logitech G512
# 6       Juhan                           NaN                        NaN
# 7        FATE              Logitech G Pro X  Logitech G Pro X Keyboard
# 8     deokdam       Logitech G Pro WIRELESS  Logitech G Pro X Keyboard
# 9       BeryL            Logitech G403 HERO              Logitech G512
# 10       Zeus       Razer Deathadder V2 PRo            Corsair K70 TKL
# 11       Oner       Logitech G Pro WIRELESS  Logitech G Pro X Keyboard
# ...

# %%
df.dropna(inplace=True)

# %%
df.to_csv('2023_LCK_Summer_Player_Equipment.csv', index=True)

# %%
df[df['Player'] == 'Peter']
# Out:
#    Player             Mouse              Keyboard
# 19  Peter  Logitech G Pro X  Steelseries Apex PRO

# %%
# Jiwoo, Grizzly, Paduck 누락
