# %%
import pandas as pd
import requests
from urllib import parse

apiKey = 'RGAPI-b472e083-dc9e-4bbc-b0ac-51856656b69a' # api키 : 매일 수정 필요
username = '그냥롤' # 유저아이디

id = parse.quote(username) # 아이디를 URL 인코딩

url = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + id +'?api_key=' + apiKey #puuid값을 가져오기 위한 주소
r = requests.get(url)
r = r.json()


puuid = r['puuid'] # puuid값을 가져옴
r
# Out:
# {'id': 'SuizpWp1ccmGtGLQWeVJ7R68fENOrM6AHnqzSPL0xR3V8z8',
#  'accountId': 'uJs5s3fmV398HmIvCTh-Mdl3X04CwNpZMdGvJQcTXybpqIo',
#  'puuid': 'oTEgUeI9IsDw1c54uEtwpXi5FvXSbKV8ZmNpfc9G4cnOb4h4O-4J7NJHTd9ILMZimWszesEcoRXmPw',
#  'name': '제 재',
#  'profileIconId': 1109,
#  'revisionDate': 1690214341000,
#  'summonerLevel': 239}

# %%
n = str(10)
rankUrl = 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/' + puuid + '/ids?queue=420&type=ranked&start=0&count='+n+'&api_key='+ apiKey
r = requests.get(rankUrl)
r = r.json()

rankId = r
print(rankId)
# Out:
# ['KR_6146459661']

# %%
for i in rankId:
    url = 'https://asia.api.riotgames.com/lol/match/v5/matches/' + i + '?api_key=' + apiKey
    r = requests.get(url)
    r = r.json()
    info = r['info']  # 전체 데이터에서 info를 추출
    part = info['participants'] # info 데이터에서 유저들의 정보 추출

result = info

# %%
df = pd.DataFrame(r['info']['participants'])

# %%
df
# Out:
#    assists  baronKills  basicPings  bountyLevel  \
# 0        7           0          23            0
# 1        8           0          18            0
# 2        5           0           6            0
# 3        5           0          20            0
# 4       13           0          34            0
# 5       15           0          28            4
# 6       15           1          49            1
# 7       17           0          40            0
# 8        9           0          21            0
# 9       18           0          11            1
#
#                                           challenges  champExperience  \
# 0  {'12AssistStreakCount': 0, 'abilityUses': 276,...            14375
# 1  {'12AssistStreakCount': 0, 'abilityUses': 640,...            19242
# 2  {'12AssistStreakCount': 0, 'abilityUses': 160,...            16743
# 3  {'12AssistStreakCount': 0, 'abilityUses': 590,...            17041
# 4  {'12AssistStreakCount': 1, 'abilityUses': 194,...            13950
# 5  {'12AssistStreakCount': 0, 'abilityUses': 307,...            19817
# 6  {'12AssistStreakCount': 0, 'abilityUses': 1335...            19821
# 7  {'12AssistStreakCount': 0, 'abilityUses': 273,...            20853
# 8  {'12AssistStreakCount': 0, 'abilityUses': 523,...            18181
# 9  {'12AssistStreakCount': 0, 'abilityUses': 274,...            14509
#
#    champLevel  championId championName  championTransform  ...  \
# 0          15         266       Aatrox                  0  ...
# 1          18         120      Hecarim                  0  ...
# 2          17          55     Katarina                  0  ...
# 3          17         157        Yasuo                  0  ...
# 4          15         117         Lulu                  0  ...
# 5          18         106     Volibear                  0  ...
# 6          18          76      Nidalee                  0  ...
# 7          18         112       Viktor                  0  ...
# 8          17          81       Ezreal                  0  ...
# 9          15          43        Karma                  0  ...
#
#    trueDamageTaken  turretKills  turretTakedowns  turretsLost  unrealKills  \
# 0              916            0                1           11            0
# 1             1670            1                1           11            0
# 2              566            0                0           11            0
# 3              428            1                1           11            0
# 4              132            0                0           11            0
# 5              302            0                2            2            0
# 6             1610            2                3            2            0
# 7              598            3                4            2            0
# 8              532            3                3            2            0
# 9             1050            1                1            2            0
#
#    visionScore  visionWardsBoughtInGame  wardsKilled  wardsPlaced    win
# 0           15                        0            2            4  False
# 1           19                        5            2            6  False
# 2           25                        4            5           11  False
# 3           22                        2            6           10  False
# 4           82                        7           14           36  False
# 5           21                        0            2           10   True
# 6           45                        6            8            7   True
# 7           35                        3            7            9   True
# 8           22                        4            3            8   True
# 9           93                       13            7           56   True
#
# [10 rows x 108 columns]

# %%
df['championName']
# Out:
# 0      Aatrox
# 1     Hecarim
# 2    Katarina
# 3       Yasuo
# 4        Lulu
# 5    Volibear
# 6     Nidalee
# 7      Viktor
# 8      Ezreal
# 9       Karma
# Name: championName, dtype: object
